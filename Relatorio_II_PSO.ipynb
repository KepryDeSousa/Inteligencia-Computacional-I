# %% [markdown]
# <a href="https://colab.research.google.com/github/KepryDeSousa/Inteligencia-Computacional-I/blob/main/Relatorio_II_PSO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Relatorio : Particle Swarm Optimization - PSO
#
# Aluno: Jarom Kepri de Sousa Marques
# > Curso :Engenharia de Energias

# %%
#bibliotecas usadas
# !pip install plotly --upgrade
import plotly.express as px
import pandas as pd
import random
from google.colab import files
import numpy as np

# %%
import math

# %% [markdown]
# ### Desafio :
# Encontrar o ponto de mínimo global da função de Ackley bidimensional (d=2) usando PSO. determinar os gráficos dos valores médio, mínimo e máximo, além da mediana da aptidão ao longo das várias gerações. Ou seja, a cada interação determinar o valores das aptidões do pior e da melhor partícula, bem como o valor médio e a mediana da aptidão naquela geração. Gere 10 figuras que mostram o deslocamento das partículas sobre o espaço de busca, ao longo das interações
# http://www.sfu.ca/~ssurjano/ackley.html
#
# http://en.wikipedia.org/wiki/Test_functions_for_optimization

# %% [markdown]
# ### Referencia para desenvolvimento
#
# Passo 1 - Iniciar aleatoriamente todos xi e vi e como nulo pi e pg.
#
# Passo 2 - Calcular o valor da função-objetivo f(x) para cada partícula.
#  O
# vetor pi de cada partícula recebe xi, enquanto pg recebe a posição
# correspondente à melhor função-objetivo do enxame.
# Passo 3 - Atualizar xi e vi aplicando as regras de atualização das
# partículas.
#
# Passo 4 - Avaliar f(x) para todas as partículas.
#
# Passo 5 - Atualizar pi caso a posição atual da i-ésima partícula
# corresponda a uma melhor função-objetivo.
#
# Passo 6 - Atualizar pg caso uma melhor solução global seja encontrada.
#
# Passo 7 - Repetir o processo a partir do Passo 3 até que uma condição de
# parada seja encontrada.

# %% [markdown]
# ## Particula
#
# Seguindo o comportamento de coleções de, REYNOLDS (1987)
# temos :
#
# a seguinte diretriz
#
# >- evitar a colisão com seus vizinhos.
# >
# >- manter a velocidade de seus vizinhos
# >
# >- tentar mover-se próximo ao centro do bando por observação
#
# Algoritmo Baseado em duas etapas proposto por:
# Kennedy [KENNEDY &
# EBERHART, 1995]
#
#
# Sem Coeficiente de Localização apenas velocidade I :
#
#  > vi = self.Bd.loc[i].Velocidade + (2*r1) * (self.Bd.loc[i].Local_Best - i ) + self.Bd.loc[i].Velocidade + (2*r2) * (self.Bd.loc[i].Global_Best - i )
#
#
#
# Coeficiente de Localização :
#
#
#  > x.append(i + self.Bd.loc[i].Velocidade)
#  >
#  > vi = self.Bd.loc[i].Velocidade + (2*r1) * (self.Bd.loc[i].Local_Best - x[i] ) + self.Bd.loc[i].Velocidade + (2*r2) * (self.Bd.loc[i].Global_Best - x[i] )
#       Velocidade_.append(vi)

# %%
w = random.uniform(0.4, 0.9) # Inercia
c1 = c2 = 2.05 # Coeficiente de aceleração 
r1 = random.uniform(0,1) #
r2 = random.uniform(0,1) # numeros pseudo-randons

# %% [markdown]
# ### Custo

# %%
# função de distância entre duas cidades
def Distancia(city1, city2):
    return math.sqrt((city1[0] - city2[0]) ** 2 + (city1[1] - city2[1]) ** 2)

# %% [markdown]
# ### Particula

# %%
class Particula():
  def __init__(self,range1, range2):
    self.range1 = range1
    self.range2 = range2
    
  def Rotas(self):
    rota1 = [random.randint(self.range1,self.range2), random.randint(self.range1,self.range2)]
    rota2 = [random.randint(self.range1,self.range2), random.randint(self.range1,self.range2)]
    rota3 = [random.randint(self.range1,self.range2), random.randint(self.range1,self.range2)]
    # construindo os valores das particulas 

    Rota_Custo_I = Distancia(rota1,rota2)
    Rota_Custo_II = Distancia(rota2,rota3)


    velocidade = 0
    data = [rota1,rota2,rota3,Rota_Custo_I,Rota_Custo_II,velocidade]
    return data

# %%
p = Particula(0,10)
p.Rotas()
# Out:
# [[0, 0], [4, 2], [2, 3], 4.47213595499958, 2.23606797749979, 0]

# %% [markdown]
# ### Bando de Aves

# %%
class Bando():
  def __init__(self, particulas, range1,range2):
    self.range1 = range1
    self.range2 = range2
    self.particulas = particulas

  def Revoada(self):
    lista = []
    for i in range(self.particulas):
      p = Particula(self.range1,self.range2)
      #sempre inicio uma nova particula
      lista.append(p.Rotas())
      data = pd.DataFrame(lista)
      data = data.rename(columns={0: 'Caminho_I', 1: 'Caminho_II',2: 'Caminho_III',3:"Distancia_I",4:"Distancia_II",5:"Velocidade"})
    
    return data

# %%
b = Bando(1000,0,100)
c = b.Revoada()
c
# Out:
#      Caminho_I Caminho_II Caminho_III  Distancia_I  Distancia_II  Velocidade
# 0    [100, 77]   [17, 17]    [72, 28]   102.415819     56.089215           0
# 1       [7, 2]   [32, 47]     [46, 4]    51.478151     45.221676           0
# 2     [80, 31]   [57, 59]    [42, 39]    36.235342     25.000000           0
# 3     [85, 21]   [37, 61]    [50, 29]    62.481997     34.539832           0
# 4     [24, 16]   [49, 82]    [34, 12]    70.576200     71.589105           0
# ..         ...        ...         ...          ...           ...         ...
# 995   [32, 11]   [49, 43]    [91, 80]    36.235342     55.973208           0
# 996   [15, 49]   [63, 18]    [59, 35]    57.140179     17.464249           0
# 997   [25, 50]   [54, 35]    [83, 65]    32.649655     41.725292           0
# 998    [3, 28]   [81, 97]    [27, 20]   104.139330     94.047860           0
# 999    [73, 2]   [26, 75]    [87, 14]    86.821656     86.267027           0
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### Local_best x Global_best

# %%
class Locais():
  def __init__(self, banco):
    self.banco = banco

  def Locais_L(self):
    Local_Best = []
    for i in range(self.banco.shape[0]):
      if self.banco.loc[i].Distancia_I < self.banco.loc[i].Distancia_II:
        Local_Best.append(self.banco.loc[i].Distancia_I)
      else:
        Local_Best.append(self.banco.loc[i].Distancia_II)
     
    self.banco['Local_Best'] = Local_Best
    return self.banco
  
  def Local_Best_Global(self):
    Global_Best = []
    self.banco['Global_Best'] = self.banco.Local_Best.min()
    return self.banco

# %%
Loc = Locais(c)
L = Loc.Locais_L()
L = Loc.Local_Best_Global()

# %%
L
# Out:
#      Caminho_I Caminho_II Caminho_III  Distancia_I  Distancia_II  Velocidade  \
# 0    [100, 77]   [17, 17]    [72, 28]   102.415819     56.089215           0
# 1       [7, 2]   [32, 47]     [46, 4]    51.478151     45.221676           0
# 2     [80, 31]   [57, 59]    [42, 39]    36.235342     25.000000           0
# 3     [85, 21]   [37, 61]    [50, 29]    62.481997     34.539832           0
# 4     [24, 16]   [49, 82]    [34, 12]    70.576200     71.589105           0
# ..         ...        ...         ...          ...           ...         ...
# 995   [32, 11]   [49, 43]    [91, 80]    36.235342     55.973208           0
# 996   [15, 49]   [63, 18]    [59, 35]    57.140179     17.464249           0
# 997   [25, 50]   [54, 35]    [83, 65]    32.649655     41.725292           0
# 998    [3, 28]   [81, 97]    [27, 20]   104.139330     94.047860           0
# 999    [73, 2]   [26, 75]    [87, 14]    86.821656     86.267027           0
#
#      Local_Best  Global_Best
# 0     56.089215          1.0
# 1     45.221676          1.0
# 2     25.000000          1.0
# 3     34.539832          1.0
# 4     70.576200          1.0
# ..          ...          ...
# 995   36.235342          1.0
# 996   17.464249          1.0
# 997   32.649655          1.0
# 998   94.047860          1.0
# 999   86.267027          1.0
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### Velocidade

# %%
class Velocidade():
  def __init__(self,Bd,r1,r2):
    self.Bd = Bd
    self.r1 = r1
    self.r2 = r2

  def V_Bd(self):
    Velocidade_ = []
    for i in range(self.Bd.shape[0]): 
      vi = self.Bd.loc[i].Velocidade + (2*r1) * (self.Bd.loc[i].Local_Best - i ) + self.Bd.loc[i].Velocidade + (2*r2) * (self.Bd.loc[i].Global_Best - i )
      Velocidade_.append(vi)

    self.Bd["Velocidade"] = Velocidade_
    return self.Bd

class Atualizar_V():
  def __init__(self,Bd):
    self.Bd = Bd.copy()

  def up(self):
    Velocidade_ = []
    x = []
    for i in range(self.Bd.shape[0]): 
      x.append(i + self.Bd.loc[i].Velocidade)
      vi = self.Bd.loc[i].Velocidade + (2*r1) * (self.Bd.loc[i].Local_Best - x[i] ) + self.Bd.loc[i].Velocidade + (2*r2) * (self.Bd.loc[i].Global_Best - x[i] )
      Velocidade_.append(vi)

    self.Bd["Velocidade"] = Velocidade_
    return self.Bd

# %%
v = Velocidade(L,r1,r2)# banco de dados, r1 e r2 foram inicialziados entre 0 e 1 no inicio
lista = v.V_Bd()

lista
# Out:
#      Caminho_I Caminho_II Caminho_III  Distancia_I  Distancia_II   Velocidade  \
# 0    [100, 77]   [17, 17]    [72, 28]   102.415819     56.089215   100.433514
# 1       [7, 2]   [32, 47]     [46, 4]    51.478151     45.221676    78.781746
# 2     [80, 31]   [57, 59]    [42, 39]    36.235342     25.000000    40.465406
# 3     [85, 21]   [37, 61]    [50, 29]    62.481997     34.539832    55.169752
# 4     [24, 16]   [49, 82]    [34, 12]    70.576200     71.589105   117.078173
# ..         ...        ...         ...          ...           ...          ...
# 995   [32, 11]   [49, 43]    [91, 80]    36.235342     55.973208 -2214.525493
# 996   [15, 49]   [63, 18]    [59, 35]    57.140179     17.464249 -2250.257591
# 997   [25, 50]   [54, 35]    [83, 65]    32.649655     41.725292 -2225.495549
# 998    [3, 28]   [81, 97]    [27, 20]   104.139330     94.047860 -2118.404539
# 999    [73, 2]   [26, 75]    [87, 14]    86.821656     86.267027 -2134.557283
#
#      Local_Best  Global_Best
# 0     56.089215          1.0
# 1     45.221676          1.0
# 2     25.000000          1.0
# 3     34.539832          1.0
# 4     70.576200          1.0
# ..          ...          ...
# 995   36.235342          1.0
# 996   17.464249          1.0
# 997   32.649655          1.0
# 998   94.047860          1.0
# 999   86.267027          1.0
#
# [1000 rows x 8 columns]

# %%
#Atualizar
#utilizando a velocidade anterior no meteodo de atualizar temos :
A = Atualizar_V(lista)
velocidade_atualizada = A.up()
velocidade_atualizada
# Out:
#    Caminho_I Caminho_II Caminho_III  Distancia_I  Distancia_II  Velocidade  \
# 0   [21, 30]   [27, 78]    [71, 34]    48.373546     62.225397   62.399102
# 1   [96, 19]   [79, 34]    [16, 56]    22.671568     66.730802   28.312789
# 2   [53, 74]  [87, 100]    [33, 60]    42.801869     67.201190   52.113474
# 3   [61, 84]   [35, 25]    [89, 42]    64.474801     56.612719   67.932579
# 4   [89, 96]    [18, 3]     [2, 84]   117.004273     82.565126   99.086689
# ..       ...        ...         ...          ...           ...         ...
# 95  [85, 77]   [37, 12]    [44, 19]    80.802228      9.899495 -140.497987
# 96  [79, 53]   [41, 40]    [47, 30]    40.162171     11.661904 -139.896282
# 97  [50, 54]   [68, 89]    [78, 80]    39.357337     13.453624 -139.257556
# 98   [1, 78]   [56, 95]    [36, 15]    57.567352     82.462113  -85.165368
# 99  [13, 82]   [29, 53]   [47, 100]    33.120990     50.328918 -117.665814
#
#     Local_Best  Global_Best
# 0    48.373546     3.605551
# 1    22.671568     3.605551
# 2    42.801869     3.605551
# 3    56.612719     3.605551
# 4    82.565126     3.605551
# ..         ...          ...
# 95    9.899495     3.605551
# 96   11.661904     3.605551
# 97   13.453624     3.605551
# 98   57.567352     3.605551
# 99   33.120990     3.605551
#
# [100 rows x 8 columns]

# %%
import plotly.graph_objs as go

# %%
data1 = px.line(velocidade_atualizada, y=velocidade_atualizada.Velocidade)
data2 = px.line(lista, y=lista.Velocidade)

figura = go.Figure()
figura.add_trace(go.Scatter(
                 y=velocidade_atualizada.Velocidade, mode="lines+markers"
                 ,name="Velocidade_up"
                  
                  ))
figura.add_trace(go.Scatter(
                 y=lista.Velocidade,  mode="lines+markers"
                 ,name="Velocidade"
                  
                  ))
figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="7f8ffddc-afc4-4ad7-8e94-9730ce62d4b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f8ffddc-afc4-4ad7-8e94-9730ce62d4b2")) {                    Plotly.newPlot(                        "7f8ffddc-afc4-4ad7-8e94-9730ce62d4b2",                        [{"mode":"lines+markers","name":"Velocidade_up","y":[62.39910156822472,28.31278861599356,52.113474006932975,67.93257877324865,99.08668861198478,81.59245821411663,33.54160924794394,70.39001921182316,23.763051611782366,48.82930599853963,49.38713273422266,74.94133613761682,43.49278271998668,-7.119626649222805,67.24445002150165,18.05959039095141,-15.57779572322065,65.968347693438,41.74976458277299,3.231560870486529,55.38718816194557,38.82982860160648,60.429940197481535,-5.506960149252774,-26.888310224545947,-25.70066946535129,17.89390097834242,22.551363049590
# Out:
#    Caminho_I Caminho_II Caminho_III  Distancia_I  Distancia_II  Velocidade
# 0    [6, 11]    [0, 11]     [8, 10]     6.000000      8.062258           0
# 1    [8, 12]    [0, 13]     [5, 14]     8.062258      5.099020           0
# 2     [4, 0]    [1, 13]      [3, 5]    13.341664      8.246211           0
# 3     [9, 6]     [4, 5]      [8, 4]     5.099020      4.123106           0
# 4     [1, 7]    [6, 15]     [6, 13]     9.433981      2.000000           0
# ..       ...        ...         ...          ...           ...         ...
# 95    [3, 8]     [7, 0]     [12, 2]     8.944272      5.385165           0
# 96    [9, 8]   [10, 10]     [13, 8]     2.236068      3.605551           0
# 97    [4, 9]    [3, 14]      [5, 7]     5.099020      7.280110           0
# 98   [15, 6]     [9, 6]     [14, 2]     6.000000      6.403124           0
# 99   [6, 11]   [13, 12]      [3, 1]     7.071068     14.866069           0
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Observando seu debandar

# %%
#iremos definir suas distancias percorridas
loc = Locais(Bando_debandado)
loc_local = loc.Locais_L()
# definindo agora o valor do bando global
Loc_Bando = loc.Local_Best_Global()

# %%
Loc_Bando
# Out:
#    Caminho_I Caminho_II Caminho_III  Distancia_I  Distancia_II  Velocidade  \
# 0    [6, 11]    [0, 11]     [8, 10]     6.000000      8.062258           0
# 1    [8, 12]    [0, 13]     [5, 14]     8.062258      5.099020           0
# 2     [4, 0]    [1, 13]      [3, 5]    13.341664      8.246211           0
# 3     [9, 6]     [4, 5]      [8, 4]     5.099020      4.123106           0
# 4     [1, 7]    [6, 15]     [6, 13]     9.433981      2.000000           0
# ..       ...        ...         ...          ...           ...         ...
# 95    [3, 8]     [7, 0]     [12, 2]     8.944272      5.385165           0
# 96    [9, 8]   [10, 10]     [13, 8]     2.236068      3.605551           0
# 97    [4, 9]    [3, 14]      [5, 7]     5.099020      7.280110           0
# 98   [15, 6]     [9, 6]     [14, 2]     6.000000      6.403124           0
# 99   [6, 11]   [13, 12]      [3, 1]     7.071068     14.866069           0
#
#     Local_Best  Global_Best
# 0     6.000000          1.0
# 1     5.099020          1.0
# 2     8.246211          1.0
# 3     4.123106          1.0
# 4     2.000000          1.0
# ..         ...          ...
# 95    5.385165          1.0
# 96    2.236068          1.0
# 97    5.099020          1.0
# 98    6.000000          1.0
# 99    7.071068          1.0
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Velocidade adquirida ao movimento

# %%
Velocidade_ = Velocidade(Loc_Bando, r1, r2)#data e valores uniformes iniciados pos inicio do relatorio
Velocidade_DoBando = Velocidade_.V_Bd() #Definindo o valor de velocidade Inicial;

Velocidade_DoBando_Atualizado = Atualizar_V(Velocidade_DoBando)# banco de dados com Velocidade
Velocidade_DoBando_Atualizado_Banco = Velocidade_DoBando_Atualizado.up()

# %%
Velocidade_DoBando # velocidade Inicial
# Out:
#    Caminho_I Caminho_II Caminho_III  Distancia_I  Distancia_II  Velocidade  \
# 0    [6, 11]    [0, 11]     [8, 10]     6.000000      8.062258   11.198638
# 1    [8, 12]    [0, 13]     [5, 14]     8.062258      5.099020    7.302480
# 2     [4, 0]    [1, 13]      [3, 5]    13.341664      8.246211   10.618217
# 3     [9, 6]     [4, 5]      [8, 4]     5.099020      4.123106    0.981783
# 4     [1, 7]    [6, 15]     [6, 13]     9.433981      2.000000   -5.091614
# ..       ...        ...         ...          ...           ...         ...
# 95    [3, 8]     [7, 0]     [12, 2]     8.944272      5.385165 -207.545900
# 96    [9, 8]   [10, 10]     [13, 8]     2.236068      3.605551 -215.447119
# 97    [4, 9]    [3, 14]      [5, 7]     5.099020      7.280110 -212.637761
# 98   [15, 6]     [9, 6]     [14, 2]     6.000000      6.403124 -213.323692
# 99   [6, 11]   [13, 12]      [3, 1]     7.071068     14.866069 -213.706608
#
#     Local_Best  Global_Best
# 0     6.000000          1.0
# 1     5.099020          1.0
# 2     8.246211          1.0
# 3     4.123106          1.0
# 4     2.000000          1.0
# ..         ...          ...
# 95    5.385165          1.0
# 96    2.236068          1.0
# 97    5.099020          1.0
# 98    6.000000          1.0
# 99    7.071068          1.0
#
# [100 rows x 8 columns]

# %%
Velocidade_DoBando_Atualizado_Banco # Velocidade Baseada no coeficiente de Indice
# Out:
#    Caminho_I Caminho_II Caminho_III  Distancia_I  Distancia_II  Velocidade  \
# 0    [6, 11]    [0, 11]     [8, 10]     6.000000      8.062258    7.939340
# 1    [8, 12]    [0, 13]     [5, 14]     8.062258      5.099020    5.177136
# 2     [4, 0]    [1, 13]      [3, 5]    13.341664      8.246211    7.527847
# 3     [9, 6]     [4, 5]      [8, 4]     5.099020      4.123106    0.696041
# 4     [1, 7]    [6, 15]     [6, 13]     9.433981      2.000000   -3.609729
# ..       ...        ...         ...          ...           ...         ...
# 95    [3, 8]     [7, 0]     [12, 2]     8.944272      5.385165 -147.140873
# 96    [9, 8]   [10, 10]     [13, 8]     2.236068      3.605551 -152.742489
# 97    [4, 9]    [3, 14]      [5, 7]     5.099020      7.280110 -150.750778
# 98   [15, 6]     [9, 6]     [14, 2]     6.000000      6.403124 -151.237073
# 99   [6, 11]   [13, 12]      [3, 1]     7.071068     14.866069 -151.508544
#
#     Local_Best  Global_Best
# 0     6.000000          1.0
# 1     5.099020          1.0
# 2     8.246211          1.0
# 3     4.123106          1.0
# 4     2.000000          1.0
# ..         ...          ...
# 95    5.385165          1.0
# 96    2.236068          1.0
# 97    5.099020          1.0
# 98    6.000000          1.0
# 99    7.071068          1.0
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Modo : birdwatcher

# %%
# aves em movimento
figura = go.Figure()
figura.add_trace(go.Scatter(
                 y=Velocidade_DoBando_Atualizado_Banco.Velocidade, mode="lines+markers"
                 ,name="Velocidade_up"
                  
                  ))
figura.add_trace(go.Scatter(
                 y=Velocidade_DoBando.Velocidade,  mode="lines+markers"
                 ,name="Velocidade"
                  
                  ))
figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="ce240d39-01c7-4b68-aa02-e43c7b468373" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce240d39-01c7-4b68-aa02-e43c7b468373")) {                    Plotly.newPlot(                        "ce240d39-01c7-4b68-aa02-e43c7b468373",                        [{"mode":"lines+markers","name":"Velocidade_up","y":[7.939339590947633,5.177135827233254,7.527846843855911,0.6960407172549683,-3.6097292145607005,-1.4449240263672343,-0.9116806495677052,-7.014498807526205,-5.83120121643095,-10.684656283557546,-1.4806380722271042,-8.310598596068694,-10.022005217245292,-14
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import e
from numpy import pi


def objective(x, y):
 return -20.0 * exp(-0.2 * sqrt(0.5 * (x**2 + y**2)))-exp(0.5 * (cos(2 * 
  pi * x)+cos(2 * pi * y))) + e + 20

#referencia : https://www.indusmic.com/post/ackley-function

# %%
x  = []
y  = []
y1 = []
x1 = []
x2 = []
y2 = []
x3 = []
y3 = []
for i in range(100):
   x.append(Velocidade_DoBando_Atualizado_Banco.loc[i].Distancia_I)
   y.append(Velocidade_DoBando_Atualizado_Banco.loc[i].Distancia_II)
   x1.append(Velocidade_DoBando_Atualizado_Banco.loc[i].Caminho_I[0])
   y1.append(Velocidade_DoBando_Atualizado_Banco.loc[i].Caminho_I[1])
   x2.append(Velocidade_DoBando_Atualizado_Banco.loc[i].Caminho_II[0])
   y2.append(Velocidade_DoBando_Atualizado_Banco.loc[i].Caminho_II[1])
   x3.append(Velocidade_DoBando_Atualizado_Banco.loc[i].Caminho_III[0])
   y3.append(Velocidade_DoBando_Atualizado_Banco.loc[i].Caminho_III[1])

 
lista = []
Caminho_I = []
Caminho_II = []
Caminho_III = []
for i in range(100):
  lista.append(objective(x[i],y[i]))
  Caminho_I.append(objective(x1[i],y1[i]))
  Caminho_II.append(objective(x2[i],y2[i]))
  Caminho_III.append(objective(x3[i],y3[i]))

# %% [markdown]
# Anckley x PSO

# %%
figura = go.Figure()
figura.add_trace(go.Scatter(
                 y=Velocidade_DoBando_Atualizado_Banco.Velocidade, mode="lines+markers"
                 ,name="Velocidade_up"
                  
                  ))
figura.add_trace(go.Scatter(
                 y=Velocidade_DoBando.Velocidade,  mode="lines+markers"
                 ,name="Velocidade"
                  
                  ))
figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="a10004de-da7b-4956-85d2-37a791282a05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a10004de-da7b-4956-85d2-37a791282a05")) {                    Plotly.newPlot(                        "a10004de-da7b-4956-85d2-37a791282a05",                        [{"mode":"lines+markers","name":"Velocidade_up","y":[7.939339590947633,5.177135827233254,7.527846843855911,0.6960407172549683,-3.6097292145607005,-1.4449240263672343,-0.9116806495677052,-7.014498807526205,-5.83120121643095,-10.684656283557546,-1.4806380722271042,-8.310598596068694,-10.022005217245292,-14.438916858242802,-17.170699426573936,-18.79494853055838,-19.978366011994552,-15.954226470814223,-14.146057328697207,-25.29194494649616,-21.332519718570595,-26.603290885660236,-27.28498748933488,-26.813720943105366,-29.512994465058643,-37.42080227043695,-32.250386438661536,-38.28593777837173,-35.92283336380427,-40.42690252199394,-30.415382180978803,-31.906824098778486,-49.82856299805513,-49.24497551112181,-52.03904420629698,-38.536627700901036,-55.28754241426586,-52.0533466829242,-55.045144457853944,-53.36562479045932,-60.61471923901292,-56.61412299842822,-61.05567075190211,-61.394218673008254,-67.53337492301316,-60.814689772460085,-69.80035126470457,-63.28530209465639,-71.2876354976984,-74.01941806602954,-69.2067726933536,-73.28056275544652,-79.54584588861127,-77.25138853683666,-72.13946873408852,-83.61393774398671,-77.96653784261079,-84.8563701523061,-87.53012653754287,-90.26190910587403,-94.26952090989255,-81.53906093277428,-92.76410485608801,-90.52934723610039,-102.32769355102009,-91.32176168107817,-96.65643241443655,-104.46944504659295,-103.28614745549771,-98.5256611052548,-105.3481784447732,-112.13626105372148,-104.66941558004012,-114.21493967049963,-115.83918877448407,-111.27467435029656,-112.66658685099307,-119.05756135504578,-123.80416290940971,-110.3626417465844,-128.31567921477122,-124.88785592918512,-129
data["Caminho_III"] = Caminho_III

# %%
data
# Out:
#     Caminho_I  Caminho_II  Caminho_III
# 0   16.600162   15.778893    16.730441
# 1   17.398406   16.818812    17.556692
# 2    8.640586   16.836043    11.231979
# 3   15.668013   11.913518    14.354712
# 4   12.642411   17.963973    17.359716
# ..        ...         ...          ...
# 95  14.025935   12.568091    16.420342
# 96  16.357051   17.293294    17.690505
# 97  15.032615   17.359716    14.075005
# 98  17.963973   15.668013    17.293294
# 99  16.600162   18.361579     7.211854
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Aplicação de formula
#
#
#  Primeiro Quartil (Q1):
#   >$Q1 = X[((n + 1) / 4)]$
#
#   Terceiro Quartil (Q3):
#   > $Q3 = X[((3n + 1) / 4)]$
#
#   Intervalo Interquartil (IQR):
#   > $IQR = Q3 - Q1$
#
#   Limite Inferior:
#   > $Limite \ Inferior = Q1 - (1.5 * IQR)$
#
#   Limite Superior:
#   >$Limite \ Superior = Q3 + (1.5 * IQR)$
#
#
#
# * Utilize o mouse por cima do grafico para avaliar os valores

# %%
px.box(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="ae130898-13f3-498a-b223-ed16a849346d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae130898-13f3-498a-b223-ed16a849346d")) {                    Plotly.newPlot(                        "ae130898-13f3-498a-b223-ed16a849346d",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_I","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_II","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Caminho_III","Cami ...

# %%
data.describe()
# Out:
#         Caminho_I  Caminho_II  Caminho_III
# count  100.000000  100.000000   100.000000
# mean    15.140085   15.452824    14.920476
# std      3.569958    3.225512     3.951556
# min      2.637531    2.637531     2.637531
# 25%     13.961693   14.442728    13.768968
# 50%     16.489253   16.522037    16.420342
# 75%     17.369388   17.721860    17.602535
# max     18.901431   18.792444    18.901431

# %%
Velocidade_DoBando.describe()
# Out:
#        Distancia_I  Distancia_II  Velocidade  Local_Best  Global_Best
# count   100.000000    100.000000  100.000000  100.000000        100.0
# mean      7.895435      8.323026 -102.214421    5.996423          1.0
# std       3.897954      3.985737   67.247621    3.211864          0.0
# min       1.000000      1.000000 -215.447119    1.000000          1.0
# 25%       5.000000      5.000000 -158.358024    3.605551          1.0
# 50%       7.280110      8.062258 -101.153768    5.242092          1.0
# 75%      11.079106     11.180340  -42.583451    7.615773          1.0
# max      16.401219     17.029386   11.198638   14.317821          1.0

# %%
Velocidade_DoBando_Atualizado_Banco.describe()
# Out:
#        Distancia_I  Distancia_II  Velocidade  Local_Best  Global_Best
# count   100.000000    100.000000  100.000000  100.000000        100.0
# mean      7.895435      8.323026  -72.465509    5.996423          1.0
# std       3.897954      3.985737   47.675592    3.211864          0.0
# min       1.000000      1.000000 -152.742489    1.000000          1.0
# 25%       5.000000      5.000000 -112.268843    3.605551          1.0
# 50%       7.280110      8.062258  -71.713552    5.242092          1.0
# 75%      11.079106     11.180340  -30.189785    7.615773          1.0
# max      16.401219     17.029386    7.939340   14.317821          1.0

# %% [markdown]
# ## Referencia :
#
# Otimização por Enxame de Partículas: KENNEDY, J.; EBERHART, R.
# C. Particle swarm optimization. Proceedings of the IEEE International
# Conference on Neural Networks, Piscataway, NJ, USA 1995
